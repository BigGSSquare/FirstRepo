# %% [markdown]
# <a href="https://colab.research.google.com/github/BigGSSquare/FirstRepo/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def temp_modelling(a,b,c,time):
  temp = 0
  temp = a*time**2 + b*time + c
  return temp

# %%
#harcoded variables
a = 2.0
b= 3.0
c = 4.0
time = 2
res = temp_modelling(a,b,c,time)
print(res)
# Out:
# 18.0

# %%
#keyboard input
a = float(input("enter the value for a :"))
b = float(input("enter the value for b :"))
c = float(input("enter the value for c :"))
time = float(input("enter the value for time :"))
print(temp_modelling(a,b,c,time))
# Out:
# enter the value for a :2
# enter the value for b :3
# enter the value for c :4
# enter the value for time :5
# 69.0

# %%
#read from file
def read_from_file(filename):
  with open(filename,'r') as f:
    lines=f.readlines()
  coeffiecients=[tuple(map(float,line.strip().split(','))) for line in lines]
  return coeffiecients

# %%
#solve for a single set of inputs
coeffiecients=read_from_file('/content/input11.txt')
a,b,c,time=coeffiecients[0]
temp=temp_modelling(a,b,c,time)
print("read from a file for weather modelling")
print("Temperature for keyboard coefficients at time",time,"hours",temp_modelling(a,b,c,time))
# Out:
# read from a file for weather modelling
# Temperature for keyboard coefficients at time 5.0 hours 69.0

# %%
#all sets
for idx,(a,b,c,time) in enumerate(coeffiecients):
  temp=temp_modelling(a,b,c,time)
  print("Temperature for keyboard coefficients at time",time,"hours",temp)
# Out:
# Temperature for keyboard coefficients at time 5.0 hours 69.0
# Temperature for keyboard coefficients at time 4.0 hours 27.0
# Temperature for keyboard coefficients at time 5.0 hours 69.0
# Temperature for keyboard coefficients at time 6.0 hours 137.0
